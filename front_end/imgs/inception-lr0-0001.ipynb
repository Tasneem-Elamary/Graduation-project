# %% [markdown]
# <h1><center>APTOS 2019 Blindness Detection</center></h1>
# <h2><center>Diabetic retinopathy - SHAP model explainability</center></h2>
# ![](https://raw.githubusercontent.com/dimitreOliveira/MachineLearning/master/Kaggle/APTOS%202019%20Blindness%20Detection/aux_img.png)
#
# In this work, I'll train a baseline ResNet50, evaluate the model, and use SHAP model explainability technique to help us better understand our model's predictions, and how we could further improve its performance.
#
# #### About [SHAP](https://github.com/slundberg/shap) from its source:
#
# <img src="https://raw.githubusercontent.com/slundberg/shap/master/docs/artwork/shap_diagram.png" width="400">
#
# ##### SHAP (SHapley Additive exPlanations) is a unified approach to explain the output of any machine learning model. SHAP connects game theory with local explanations, uniting several previous methods [1-7] and representing the only possible consistent and locally accurate additive feature attribution method based on expectations (see our [papers](https://github.com/slundberg/shap#citations) for details).

# %% [markdown]
# ## Dependencies

# %%
import os
import shap
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, cohen_kappa_score
from keras.models import Model
from keras import optimizers, applications
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input

# Set seeds to make the experiment more reproducible.
from tensorflow.python.framework import random_seed
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random_seed.set_seed(seed)

seed = 0
seed_everything(seed)

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
train = pd.read_csv('../input/aptos2019-blindness-detection/train.csv')
test = pd.read_csv('../input/aptos2019-blindness-detection/test.csv')
print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])

# Preprocecss data
train["id_code"] = train["id_code"].apply(lambda x: x + ".png")
test["id_code"] = test["id_code"].apply(lambda x: x + ".png")
train['diagnosis'] = train['diagnosis'].astype('str')
display(train.head())
# Out:
# Number of train samples:  3662
# Number of test samples:  1928
#             id_code diagnosis
# 0  000c1434d8d7.png         2
# 1  001639a390f0.png         4
# 2  0024cdab0c1e.png         1
# 3  002c21358ce6.png         0
# 4  005b95c28852.png         0

# %% [markdown]
# # Model parameters

# %%
# Model parameters
BATCH_SIZE = 8
EPOCHS = 40
WARMUP_EPOCHS = 2
LEARNING_RATE = 0.0001
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 320
WIDTH = 320
CANAL = 3
N_CLASSES = train['diagnosis'].nunique()
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

# %% [markdown]
# ## Train test split

# %% [markdown]
# **train_test_split** splits arrays or matrices into random train and test subsets. That means that everytime you run it without specifying random_state, you will get a different result, this is expected behavior.

# %%
X_train, X_val = train_test_split(train, test_size=0.2, random_state=seed)

# %% [markdown]
# # Data generator

# %% [markdown]
# **ImageDataGenerator** Generate batches of tensor image data with real-time data augmentation
#
# We can make the use of ImageDataGenerator class by passing the appropriate parameters and passing the required input to it. How many images will be generated depends on the size of the batch and the input data set that contains a specific number of inputs? For example, if the size of the batch is defined as 10 and we pass 1000 images in the input of outset of data then the number of images that will generate in each and every iteration of the training will be 10.
#
# *  **rescaling factor**. Defaults to None. we multiply the data by the value provided.
# *  **Rotation**. Degree range for random rotations.
# *  **horizontal_flip** Boolean. Randomly flip inputs horizontally.
# *  **vertical_flip** Boolean. Randomly flip inputs vertically.
#
# * **categorical**: 2D numpy array of encoded labels. Supports multi-label output.
#
# * **Batch Size**: For instance, let's say you have 1050 training samples and you want to set up a batch_size equal to 100. The algorithm takes the first 100 samples (from 1st to 100th) from the training dataset and trains the network. Next, it takes the second 100 samples (from 101st to 200th) and trains the network again. We can keep doing this procedure until we have propagated all samples through of the network. Problem might happen with the last set of samples. In our example, we've used 1050 which is not divisible by 100 without remainder.
#
# * **seed**: Optional random seed for shuffling

# %%
train_datagen=ImageDataGenerator(rescale=1./255, 
                                 rotation_range=360,
                                 horizontal_flip=True,
                                 vertical_flip=True)

train_generator=train_datagen.flow_from_dataframe(
    dataframe=X_train,
    directory="../input/aptos2019-blindness-detection/train_images/",
    x_col="id_code",
    y_col="diagnosis",
    class_mode="categorical",
    batch_size=BATCH_SIZE,
    target_size=(HEIGHT, WIDTH),
    seed=0)

validation_datagen = ImageDataGenerator(rescale=1./255)

valid_generator=validation_datagen.flow_from_dataframe(
    dataframe=X_val,
    directory="../input/aptos2019-blindness-detection/train_images/",
    x_col="id_code",
    y_col="diagnosis",
    class_mode="categorical", 
    batch_size=BATCH_SIZE,   
    target_size=(HEIGHT, WIDTH),
    seed=0)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/aptos2019-blindness-detection/test_images/",
        x_col="id_code",
        batch_size=1,
        class_mode=None,
        shuffle=False,
        target_size=(HEIGHT, WIDTH),
        seed=0)
# Out:
# Found 2929 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames belonging to 5 classes.
# Found 1928 validated image filenames.

# %% [markdown]
# # Model

# %% [markdown]
# **include_top**:  whether to include the fully-connected layer at the top of the network.
# > **weights**:
# * one of None (random initialization)
# * 'imagenet' (pre-training on ImageNet)
# * the path to the weights file to be loaded

# %% [markdown]
# # Train top layers

# %%
import tensorflow as tf
def create_model(input_shape, n_out):
    input_tensor = Input(shape=input_shape)
    #base_model = applications.ResNet50(weights=None, 
                                       #include_top=False,
                                       #input_tensor=input_tensor)',
    base_model= applications.InceptionResNetV2(weights=None,
                                include_top=False,
                                input_tensor=input_tensor)
    base_model.load_weights('/kaggle/input/inceptionresnetv2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5')

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)  #dropout as averaging together the results of many individual neural networks
    x = Dense(2048, activation='relu')(x)   #It's depend more on number of classes.
    x = Dropout(0.5)(x)
    final_output = Dense(n_out, activation='softmax', name='final_output')(x) 
    #The softmax activation function transforms the raw outputs of the neural network into a vector of probabilities
    
    model = Model(input_tensor, final_output)
    
    return model

# %%
model = create_model(input_shape=(HEIGHT, WIDTH, CANAL), n_out=N_CLASSES)

for layer in model.layers:
    layer.trainable = False
# the amount of layers that you want to freeze (not train)
# the good practice is from top to bottom. You should tune the number of frozen layers by yourself. 
# But take into account that the more unfrozen layers you have, the slower is training.

for i in range(-5, 0):
    model.layers[i].trainable = True
    
class_weights = class_weight.compute_class_weight('balanced', classes = np.unique(train['diagnosis'].astype('int').values), y= train['diagnosis'].astype('int').values)
# and the class weights for the training set can be computed like this

class_weights_dict = {}
for i, weight in enumerate(class_weights):
    class_weights_dict[i] = weight


metric_list = ["accuracy"]
optimizer = optimizers.Adam(lr=WARMUP_LEARNING_RATE)
model.compile(optimizer=optimizer, loss='categorical_crossentropy',  metrics=metric_list)
# categorical_crossentropy: Used as a loss function for multi-class classification model 
#where there are two or more output labels. The output label is assigned one-hot category encoding value in form of 0s and 1. 
#The output label, if present in integer form, is converted into categorical encoding using keras.utils to_categorical method.
model.summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 320, 320, 3  0           []
#                                 )]
#
#  conv2d_1015 (Conv2D)           (None, 159, 159, 32  864         ['input_19[0][0]']
#                                 )
#
#  batch_normalization_1015 (Batc  (None, 159, 159, 32  96         ['conv2d_1015[0][0]']
#  hNormalization)                )
#
#  activation_1015 (Activation)   (None, 159, 159, 32  0           ['batch_normalization_1015[0][0]'
#                                 )                                ]
#
#  conv2d_1016 (Conv2D)           (None, 157, 157, 32  9216        ['activation_1015[0][0]']
#                                 )
#
#  batch_normalization_1016 (Batc  (None, 157, 157, 32  96         ['conv2d_1016[0][0]']
#  hNormalization)                )
#
#  activation_1016 (Activation)   (None, 157, 157, 32  0           ['batch_normalization_1016[0][0]'
#                                 )                                ]
#
#  conv2d_1017 (Conv2D)           (None, 157, 157, 64  18432       ['activation_1016[0][0]']
#                                 )
#
#  batch_normalization_1017 (Batc  (None, 157, 157, 64  192        ['conv2d_1017[0][0]']
#  hNormalization)                )
#
#  activation_1017 (Activation)   (None, 157, 157, 64  0           ['batch_normalization_1017[0][0]'
#                                 )                                ]
#
#  max_pooling2d_20 (MaxPooling2D  (None, 78, 78, 64)  0           ['activation_1017[0][0]']
#  )
#
#  conv2d_1018 (Conv2D)           (None, 78, 78, 80)   5120        ['max_pooling2d_20[0][0]']
#
#  batch_normalization_1018 (Batc  (None, 78, 78, 80)  240         ['conv2d_1018[0][0]']
#  hNormalization)
#
#  activation_1018 (Activation)   (None, 78, 78, 80)   0           ['batch_normalization_1018[0][0]'
#                                                                  ]
#
#  conv2d_1019 (Conv2D)           (None, 76, 76, 192)  138240      ['activation_1018[0][0]']
#
#  batch_normalization_1019 (Batc  (None, 76, 76, 192)  576        ['conv2d_1019[0][0]']
#  hNormalization)
#
#  activation_1019 (Activation)   (None, 76, 76, 192)  0           ['batch_normalization_1019[0][0]'
#                                                                  ]
#
#  max_pooling2d_21 (MaxPooling2D  (None, 37, 37, 192)  0          ['activation_1019[0][0]']
#  )
#
#  conv2d_1023 (Conv2D)           (None, 37, 37, 64)   12288       ['max_pooling2d_21[0][0]']
#
#  batch_normalization_1023 (Batc  (None, 37, 37, 64)  192         ['conv2d_1023[0][0]']
#  hNormalization)
#
#  activation_1023 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1023[0][0]'
#                                                                  ]
#
#  conv2d_1021 (Conv2D)           (None, 37, 37, 48)   9216        ['max_pooling2d_21[0][0]']
#
#  conv2d_1024 (Conv2D)           (None, 37, 37, 96)   55296       ['activation_1023[0][0]']
#
#  batch_normalization_1021 (Batc  (None, 37, 37, 48)  144         ['conv2d_1021[0][0]']
#  hNormalization)
#
#  batch_normalization_1024 (Batc  (None, 37, 37, 96)  288         ['conv2d_1024[0][0]']
#  hNormalization)
#
#  activation_1021 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1021[0][0]'
#                                                                  ]
#
#  activation_1024 (Activation)   (None, 37, 37, 96)   0           ['batch_normalization_1024[0][0]'
#                                                                  ]
#
#  average_pooling2d_5 (AveragePo  (None, 37, 37, 192)  0          ['max_pooling2d_21[0][0]']
#  oling2D)
#
#  conv2d_1020 (Conv2D)           (None, 37, 37, 96)   18432       ['max_pooling2d_21[0][0]']
#
#  conv2d_1022 (Conv2D)           (None, 37, 37, 64)   76800       ['activation_1021[0][0]']
#
#  conv2d_1025 (Conv2D)           (None, 37, 37, 96)   82944       ['activation_1024[0][0]']
#
#  conv2d_1026 (Conv2D)           (None, 37, 37, 64)   12288       ['average_pooling2d_5[0][0]']
#
#  batch_normalization_1020 (Batc  (None, 37, 37, 96)  288         ['conv2d_1020[0][0]']
#  hNormalization)
#
#  batch_normalization_1022 (Batc  (None, 37, 37, 64)  192         ['conv2d_1022[0][0]']
#  hNormalization)
#
#  batch_normalization_1025 (Batc  (None, 37, 37, 96)  288         ['conv2d_1025[0][0]']
#  hNormalization)
#
#  batch_normalization_1026 (Batc  (None, 37, 37, 64)  192         ['conv2d_1026[0][0]']
#  hNormalization)
#
#  activation_1020 (Activation)   (None, 37, 37, 96)   0           ['batch_normalization_1020[0][0]'
#                                                                  ]
#
#  activation_1022 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1022[0][0]'
#                                                                  ]
#
#  activation_1025 (Activation)   (None, 37, 37, 96)   0           ['batch_normalization_1025[0][0]'
#                                                                  ]
#
#  activation_1026 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1026[0][0]'
#                                                                  ]
#
#  mixed_5b (Concatenate)         (None, 37, 37, 320)  0           ['activation_1020[0][0]',
#                                                                   'activation_1022[0][0]',
#                                                                   'activation_1025[0][0]',
#                                                                   'activation_1026[0][0]']
#
#  conv2d_1030 (Conv2D)           (None, 37, 37, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_1030 (Batc  (None, 37, 37, 32)  96          ['conv2d_1030[0][0]']
#  hNormalization)
#
#  activation_1030 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1030[0][0]'
#                                                                  ]
#
#  conv2d_1028 (Conv2D)           (None, 37, 37, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_1031 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1030[0][0]']
#
#  batch_normalization_1028 (Batc  (None, 37, 37, 32)  96          ['conv2d_1028[0][0]']
#  hNormalization)
#
#  batch_normalization_1031 (Batc  (None, 37, 37, 48)  144         ['conv2d_1031[0][0]']
#  hNormalization)
#
#  activation_1028 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1028[0][0]'
#                                                                  ]
#
#  activation_1031 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1031[0][0]'
#                                                                  ]
#
#  conv2d_1027 (Conv2D)           (None, 37, 37, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_1029 (Conv2D)           (None, 37, 37, 32)   9216        ['activation_1028[0][0]']
#
#  conv2d_1032 (Conv2D)           (None, 37, 37, 64)   27648       ['activation_1031[0][0]']
#
#  batch_normalization_1027 (Batc  (None, 37, 37, 32)  96          ['conv2d_1027[0][0]']
#  hNormalization)
#
#  batch_normalization_1029 (Batc  (None, 37, 37, 32)  96          ['conv2d_1029[0][0]']
#  hNormalization)
#
#  batch_normalization_1032 (Batc  (None, 37, 37, 64)  192         ['conv2d_1032[0][0]']
#  hNormalization)
#
#  activation_1027 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1027[0][0]'
#                                                                  ]
#
#  activation_1029 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1029[0][0]'
#                                                                  ]
#
#  activation_1032 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1032[0][0]'
#                                                                  ]
#
#  block35_1_mixed (Concatenate)  (None, 37, 37, 128)  0           ['activation_1027[0][0]',
#                                                                   'activation_1029[0][0]',
#                                                                   'activation_1032[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 37, 37, 320)  41280       ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_200 (Custom  (None, 37, 37, 320)  0          ['mixed_5b[0][0]',
#  ScaleLayer)                                                      'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 37, 37, 320)  0           ['custom_scale_layer_200[0][0]']
#
#  conv2d_1036 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_1036 (Batc  (None, 37, 37, 32)  96          ['conv2d_1036[0][0]']
#  hNormalization)
#
#  activation_1036 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1036[0][0]'
#                                                                  ]
#
#  conv2d_1034 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_1037 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1036[0][0]']
#
#  batch_normalization_1034 (Batc  (None, 37, 37, 32)  96          ['conv2d_1034[0][0]']
#  hNormalization)
#
#  batch_normalization_1037 (Batc  (None, 37, 37, 48)  144         ['conv2d_1037[0][0]']
#  hNormalization)
#
#  activation_1034 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1034[0][0]'
#                                                                  ]
#
#  activation_1037 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1037[0][0]'
#                                                                  ]
#
#  conv2d_1033 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_1035 (Conv2D)           (None, 37, 37, 32)   9216        ['activation_1034[0][0]']
#
#  conv2d_1038 (Conv2D)           (None, 37, 37, 64)   27648       ['activation_1037[0][0]']
#
#  batch_normalization_1033 (Batc  (None, 37, 37, 32)  96          ['conv2d_1033[0][0]']
#  hNormalization)
#
#  batch_normalization_1035 (Batc  (None, 37, 37, 32)  96          ['conv2d_1035[0][0]']
#  hNormalization)
#
#  batch_normalization_1038 (Batc  (None, 37, 37, 64)  192         ['conv2d_1038[0][0]']
#  hNormalization)
#
#  activation_1033 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1033[0][0]'
#                                                                  ]
#
#  activation_1035 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1035[0][0]'
#                                                                  ]
#
#  activation_1038 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1038[0][0]'
#                                                                  ]
#
#  block35_2_mixed (Concatenate)  (None, 37, 37, 128)  0           ['activation_1033[0][0]',
#                                                                   'activation_1035[0][0]',
#                                                                   'activation_1038[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 37, 37, 320)  41280       ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_201 (Custom  (None, 37, 37, 320)  0          ['block35_1_ac[0][0]',
#  ScaleLayer)                                                      'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 37, 37, 320)  0           ['custom_scale_layer_201[0][0]']
#
#  conv2d_1042 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_1042 (Batc  (None, 37, 37, 32)  96          ['conv2d_1042[0][0]']
#  hNormalization)
#
#  activation_1042 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1042[0][0]'
#                                                                  ]
#
#  conv2d_1040 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_1043 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1042[0][0]']
#
#  batch_normalization_1040 (Batc  (None, 37, 37, 32)  96          ['conv2d_1040[0][0]']
#  hNormalization)
#
#  batch_normalization_1043 (Batc  (None, 37, 37, 48)  144         ['conv2d_1043[0][0]']
#  hNormalization)
#
#  activation_1040 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1040[0][0]'
#                                                                  ]
#
#  activation_1043 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1043[0][0]'
#                                                                  ]
#
#  conv2d_1039 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_1041 (Conv2D)           (None, 37, 37, 32)   9216        ['activation_1040[0][0]']
#
#  conv2d_1044 (Conv2D)           (None, 37, 37, 64)   27648       ['activation_1043[0][0]']
#
#  batch_normalization_1039 (Batc  (None, 37, 37, 32)  96          ['conv2d_1039[0][0]']
#  hNormalization)
#
#  batch_normalization_1041 (Batc  (None, 37, 37, 32)  96          ['conv2d_1041[0][0]']
#  hNormalization)
#
#  batch_normalization_1044 (Batc  (None, 37, 37, 64)  192         ['conv2d_1044[0][0]']
#  hNormalization)
#
#  activation_1039 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1039[0][0]'
#                                                                  ]
#
#  activation_1041 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1041[0][0]'
#                                                                  ]
#
#  activation_1044 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1044[0][0]'
#                                                                  ]
#
#  block35_3_mixed (Concatenate)  (None, 37, 37, 128)  0           ['activation_1039[0][0]',
#                                                                   'activation_1041[0][0]',
#                                                                   'activation_1044[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 37, 37, 320)  41280       ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_202 (Custom  (None, 37, 37, 320)  0          ['block35_2_ac[0][0]',
#  ScaleLayer)                                                      'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 37, 37, 320)  0           ['custom_scale_layer_202[0][0]']
#
#  conv2d_1048 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_1048 (Batc  (None, 37, 37, 32)  96          ['conv2d_1048[0][0]']
#  hNormalization)
#
#  activation_1048 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1048[0][0]'
#                                                                  ]
#
#  conv2d_1046 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_1049 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1048[0][0]']
#
#  batch_normalization_1046 (Batc  (None, 37, 37, 32)  96          ['conv2d_1046[0][0]']
#  hNormalization)
#
#  batch_normalization_1049 (Batc  (None, 37, 37, 48)  144         ['conv2d_1049[0][0]']
#  hNormalization)
#
#  activation_1046 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1046[0][0]'
#                                                                  ]
#
#  activation_1049 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1049[0][0]'
#                                                                  ]
#
#  conv2d_1045 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_1047 (Conv2D)           (None, 37, 37, 32)   9216        ['activation_1046[0][0]']
#
#  conv2d_1050 (Conv2D)           (None, 37, 37, 64)   27648       ['activation_1049[0][0]']
#
#  batch_normalization_1045 (Batc  (None, 37, 37, 32)  96          ['conv2d_1045[0][0]']
#  hNormalization)
#
#  batch_normalization_1047 (Batc  (None, 37, 37, 32)  96          ['conv2d_1047[0][0]']
#  hNormalization)
#
#  batch_normalization_1050 (Batc  (None, 37, 37, 64)  192         ['conv2d_1050[0][0]']
#  hNormalization)
#
#  activation_1045 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1045[0][0]'
#                                                                  ]
#
#  activation_1047 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1047[0][0]'
#                                                                  ]
#
#  activation_1050 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1050[0][0]'
#                                                                  ]
#
#  block35_4_mixed (Concatenate)  (None, 37, 37, 128)  0           ['activation_1045[0][0]',
#                                                                   'activation_1047[0][0]',
#                                                                   'activation_1050[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 37, 37, 320)  41280       ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_203 (Custom  (None, 37, 37, 320)  0          ['block35_3_ac[0][0]',
#  ScaleLayer)                                                      'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 37, 37, 320)  0           ['custom_scale_layer_203[0][0]']
#
#  conv2d_1054 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_1054 (Batc  (None, 37, 37, 32)  96          ['conv2d_1054[0][0]']
#  hNormalization)
#
#  activation_1054 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1054[0][0]'
#                                                                  ]
#
#  conv2d_1052 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_1055 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1054[0][0]']
#
#  batch_normalization_1052 (Batc  (None, 37, 37, 32)  96          ['conv2d_1052[0][0]']
#  hNormalization)
#
#  batch_normalization_1055 (Batc  (None, 37, 37, 48)  144         ['conv2d_1055[0][0]']
#  hNormalization)
#
#  activation_1052 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1052[0][0]'
#                                                                  ]
#
#  activation_1055 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1055[0][0]'
#                                                                  ]
#
#  conv2d_1051 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_1053 (Conv2D)           (None, 37, 37, 32)   9216        ['activation_1052[0][0]']
#
#  conv2d_1056 (Conv2D)           (None, 37, 37, 64)   27648       ['activation_1055[0][0]']
#
#  batch_normalization_1051 (Batc  (None, 37, 37, 32)  96          ['conv2d_1051[0][0]']
#  hNormalization)
#
#  batch_normalization_1053 (Batc  (None, 37, 37, 32)  96          ['conv2d_1053[0][0]']
#  hNormalization)
#
#  batch_normalization_1056 (Batc  (None, 37, 37, 64)  192         ['conv2d_1056[0][0]']
#  hNormalization)
#
#  activation_1051 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1051[0][0]'
#                                                                  ]
#
#  activation_1053 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1053[0][0]'
#                                                                  ]
#
#  activation_1056 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1056[0][0]'
#                                                                  ]
#
#  block35_5_mixed (Concatenate)  (None, 37, 37, 128)  0           ['activation_1051[0][0]',
#                                                                   'activation_1053[0][0]',
#                                                                   'activation_1056[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 37, 37, 320)  41280       ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_204 (Custom  (None, 37, 37, 320)  0          ['block35_4_ac[0][0]',
#  ScaleLayer)                                                      'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 37, 37, 320)  0           ['custom_scale_layer_204[0][0]']
#
#  conv2d_1060 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_1060 (Batc  (None, 37, 37, 32)  96          ['conv2d_1060[0][0]']
#  hNormalization)
#
#  activation_1060 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1060[0][0]'
#                                                                  ]
#
#  conv2d_1058 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_1061 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1060[0][0]']
#
#  batch_normalization_1058 (Batc  (None, 37, 37, 32)  96          ['conv2d_1058[0][0]']
#  hNormalization)
#
#  batch_normalization_1061 (Batc  (None, 37, 37, 48)  144         ['conv2d_1061[0][0]']
#  hNormalization)
#
#  activation_1058 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1058[0][0]'
#                                                                  ]
#
#  activation_1061 (Activation)   (None, 37, 37, 48)   0           ['batch_normalization_1061[0][0]'
#                                                                  ]
#
#  conv2d_1057 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_1059 (Conv2D)           (None, 37, 37, 32)   9216        ['activation_1058[0][0]']
#
#  conv2d_1062 (Conv2D)           (None, 37, 37, 64)   27648       ['activation_1061[0][0]']
#
#  batch_normalization_1057 (Batc  (None, 37, 37, 32)  96          ['conv2d_1057[0][0]']
#  hNormalization)
#
#  batch_normalization_1059 (Batc  (None, 37, 37, 32)  96          ['conv2d_1059[0][0]']
#  hNormalization)
#
#  batch_normalization_1062 (Batc  (None, 37, 37, 64)  192         ['conv2d_1062[0][0]']
#  hNormalization)
#
#  activation_1057 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1057[0][0]'
#                                                                  ]
#
#  activation_1059 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1059[0][0]'
#                                                                  ]
#
#  activation_1062 (Activation)   (None, 37, 37, 64)   0           ['batch_normalization_1062[0][0]'
#                                                                  ]
#
#  block35_6_mixed (Concatenate)  (None, 37, 37, 128)  0           ['activation_1057[0][0]',
#                                                                   'activation_1059[0][0]',
#                                                                   'activation_1062[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 37, 37, 320)  41280       ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_205 (Custom  (None, 37, 37, 320)  0          ['block35_5_ac[0][0]',
#  ScaleLayer)                                                      'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 37, 37, 320)  0           ['custom_scale_layer_205[0][0]']
#
#  conv2d_1066 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_1066 (Batc  (None, 37, 37, 32)  96          ['conv2d_1066[0][0]']
#  hNormalization)
#
#  activation_1066 (Activation)   (None, 37, 37, 32)   0           ['batch_normalization_1066[0][0]'
#                                                                  ]
#
#  conv2d_1064 (Conv2D)           (None, 37, 37, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_1067 (Conv2D)           (None, 37, 37, 48)   13824       ['activation_1066[0][0]']
# ...
#                                                                  ]
#
#  activation_1205 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1205[0][0]'
#                                                                  ]
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_1202[0][0]',
#                                                                   'activation_1205[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_236 (Custom  (None, 8, 8, 2080)  0           ['block8_6_ac[0][0]',
#  ScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_236[0][0]']
#
#  conv2d_1207 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_1207 (Batc  (None, 8, 8, 192)   576         ['conv2d_1207[0][0]']
#  hNormalization)
#
#  activation_1207 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1207[0][0]'
#                                                                  ]
#
#  conv2d_1208 (Conv2D)           (None, 8, 8, 224)    129024      ['activation_1207[0][0]']
#
#  batch_normalization_1208 (Batc  (None, 8, 8, 224)   672         ['conv2d_1208[0][0]']
#  hNormalization)
#
#  activation_1208 (Activation)   (None, 8, 8, 224)    0           ['batch_normalization_1208[0][0]'
#                                                                  ]
#
#  conv2d_1206 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_1209 (Conv2D)           (None, 8, 8, 256)    172032      ['activation_1208[0][0]']
#
#  batch_normalization_1206 (Batc  (None, 8, 8, 192)   576         ['conv2d_1206[0][0]']
#  hNormalization)
#
#  batch_normalization_1209 (Batc  (None, 8, 8, 256)   768         ['conv2d_1209[0][0]']
#  hNormalization)
#
#  activation_1206 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1206[0][0]'
#                                                                  ]
#
#  activation_1209 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1209[0][0]'
#                                                                  ]
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_1206[0][0]',
#                                                                   'activation_1209[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_237 (Custom  (None, 8, 8, 2080)  0           ['block8_7_ac[0][0]',
#  ScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_237[0][0]']
#
#  conv2d_1211 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_1211 (Batc  (None, 8, 8, 192)   576         ['conv2d_1211[0][0]']
#  hNormalization)
#
#  activation_1211 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1211[0][0]'
#                                                                  ]
#
#  conv2d_1212 (Conv2D)           (None, 8, 8, 224)    129024      ['activation_1211[0][0]']
#
#  batch_normalization_1212 (Batc  (None, 8, 8, 224)   672         ['conv2d_1212[0][0]']
#  hNormalization)
#
#  activation_1212 (Activation)   (None, 8, 8, 224)    0           ['batch_normalization_1212[0][0]'
#                                                                  ]
#
#  conv2d_1210 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_1213 (Conv2D)           (None, 8, 8, 256)    172032      ['activation_1212[0][0]']
#
#  batch_normalization_1210 (Batc  (None, 8, 8, 192)   576         ['conv2d_1210[0][0]']
#  hNormalization)
#
#  batch_normalization_1213 (Batc  (None, 8, 8, 256)   768         ['conv2d_1213[0][0]']
#  hNormalization)
#
#  activation_1210 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1210[0][0]'
#                                                                  ]
#
#  activation_1213 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1213[0][0]'
#                                                                  ]
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_1210[0][0]',
#                                                                   'activation_1213[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_238 (Custom  (None, 8, 8, 2080)  0           ['block8_8_ac[0][0]',
#  ScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_238[0][0]']
#
#  conv2d_1215 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_1215 (Batc  (None, 8, 8, 192)   576         ['conv2d_1215[0][0]']
#  hNormalization)
#
#  activation_1215 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1215[0][0]'
#                                                                  ]
#
#  conv2d_1216 (Conv2D)           (None, 8, 8, 224)    129024      ['activation_1215[0][0]']
#
#  batch_normalization_1216 (Batc  (None, 8, 8, 224)   672         ['conv2d_1216[0][0]']
#  hNormalization)
#
#  activation_1216 (Activation)   (None, 8, 8, 224)    0           ['batch_normalization_1216[0][0]'
#                                                                  ]
#
#  conv2d_1214 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_1217 (Conv2D)           (None, 8, 8, 256)    172032      ['activation_1216[0][0]']
#
#  batch_normalization_1214 (Batc  (None, 8, 8, 192)   576         ['conv2d_1214[0][0]']
#  hNormalization)
#
#  batch_normalization_1217 (Batc  (None, 8, 8, 256)   768         ['conv2d_1217[0][0]']
#  hNormalization)
#
#  activation_1214 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1214[0][0]'
#                                                                  ]
#
#  activation_1217 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1217[0][0]'
#                                                                  ]
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_1214[0][0]',
#                                                                   'activation_1217[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_239 (Custom  (None, 8, 8, 2080)  0           ['block8_9_ac[0][0]',
#  ScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['custom_scale_layer_239[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_16 (G  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  lobalAveragePooling2D)
#
#  dropout_32 (Dropout)           (None, 1536)         0           ['global_average_pooling2d_16[0][
#                                                                  0]']
#
#  dense_16 (Dense)               (None, 2048)         3147776     ['dropout_32[0][0]']
#
#  dropout_33 (Dropout)           (None, 2048)         0           ['dense_16[0][0]']
#
#  final_output (Dense)           (None, 5)            10245       ['dropout_33[0][0]']
#
# ==================================================================================================
# Total params: 57,494,757
# Trainable params: 3,158,021
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
print(class_weights)
# Out:
# [0.40576177 1.97945946 0.73313313 3.79481865 2.48271186]

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

history_warmup = model.fit_generator(generator=train_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN, #it specifies the total number of steps taken from the generator
                                     validation_data=valid_generator,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=WARMUP_EPOCHS,
                                     class_weight=class_weights_dict,
                                     verbose=1).history
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# Cell In[105], line 4
#       1 STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
#       2 STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
# ----> 4 history_warmup = model.fit_generator(generator=train_generator,
#       5                                      steps_per_epoch=STEP_SIZE_TRAIN, #it specifies the total number of steps taken from the generator
#       6                                      validation_data=valid_generator,
#       7                                      validation_steps=STEP_SIZE_VALID,
#       8                                      epochs=WARMUP_EPOCHS,
#       9                                      class_weight=class_weights_dict,
#      10                                      verbose=1).history
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:2636, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2624 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2625
#    2626 DEPRECATED:
#    2627   `Model.fit` now supports generators, so there is no longer any need to
#    2628   use this endpoint.
#    2629 """
#    2630 warnings.warn(
#    2631     "`Model.fit_generator` is deprecated and "
#    2632     "will be removed in a future version. "
#    2633     "Please use `Model.fit`, which supports generators.",
#    2634     stacklevel=2,
#    2635 )
# -> 2636 return self.fit(
#    2637     generator,
#    2638     steps_per_epoch=steps_per_epoch,
#    2639     epochs=epochs,
#    2640     verbose=verbose,
#    2641     callbacks=callbacks,
#    2642     validation_data=validation_data,
#    2643     validation_steps=validation_steps,
#    2644     validation_freq=validation_freq,
#    2645     class_weight=class_weight,
#    2646     max_queue_size=max_queue_size,
#    2647     workers=workers,
#    2648     use_multiprocessing=use_multiprocessing,
#    2649     shuffle=shuffle,
#    2650     initial_epoch=initial_epoch,
#    2651 )
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1200, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1198 except Exception as e:  # pylint:disable=broad-except
#    1199   if hasattr(e, "ag_error_metadata"):
# -> 1200     raise e.ag_error_metadata.to_exception(e)
#    1201   else:
#    1202     raise
#
# StagingError: in user code:
#
#     File "/opt/conda/lib/python3.10/site-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/opt/conda/lib/python3.10/site-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/opt/conda/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/opt/conda/lib/python3.10/site-packages/keras/engine/training.py", line 1054, in train_step
#         self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/opt/conda/lib/python3.10/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 585, in minimize
#         grads_and_vars = self._compute_gradients(
#     File "/opt/conda/lib/python3.10/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 643, in _compute_gradients
#         grads_and_vars = self._get_gradients(
#     File "/opt/conda/lib/python3.10/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 519, in _get_gradients
#         grads = tape.gradient(loss, var_list, grad_loss)
#
#     LookupError: gradient registry has no entry for: shap_DivNoNan

# %% [markdown]
# # Fine-tune the complete model

# %%
for layer in model.layers:
    layer.trainable = True

es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)

callback_list = [es, rlrop]
optimizer = optimizers.Adam(lr=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='categorical_crossentropy',  metrics=metric_list)
model.summary()

# %%
history_finetunning = model.fit_generator(generator=train_generator,
                                          steps_per_epoch=STEP_SIZE_TRAIN,
                                          validation_data=valid_generator,
                                          validation_steps=STEP_SIZE_VALID,
                                          epochs=EPOCHS,
                                          callbacks=callback_list,
                                          class_weight=class_weights_dict,
                                          verbose=1).history

# %% [markdown]
# # Model loss graph

# %%
history = {'loss': history_warmup['loss'] + history_finetunning['loss'], 
           'val_loss': history_warmup['val_loss'] + history_finetunning['val_loss'], 
           'acc': history_warmup['accuracy'] + history_finetunning['accuracy'], 
           'val_acc': history_warmup['val_accuracy'] + history_finetunning['val_accuracy']}

sns.set_style("whitegrid")
fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(20, 14))

ax1.plot(history['loss'], label='Train loss')
ax1.plot(history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('Loss')

ax2.plot(history['acc'], label='Train accuracy')
ax2.plot(history['val_acc'], label='Validation accuracy')
ax2.legend(loc='best')
ax2.set_title('Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()

# %% [markdown]
# # Model Evaluation
#
# ## Confusion Matrix

# %%
# Create empty arays to keep the predictions and labels
lastFullTrainPred = np.empty((0, N_CLASSES))
lastFullTrainLabels = np.empty((0, N_CLASSES))
lastFullValPred = np.empty((0, N_CLASSES))
lastFullValLabels = np.empty((0, N_CLASSES))

# Add train predictions and labels
for i in range(STEP_SIZE_TRAIN+1):
    im, lbl = next(train_generator)
    scores = model.predict(im, batch_size=train_generator.batch_size)
    lastFullTrainPred = np.append(lastFullTrainPred, scores, axis=0)
    lastFullTrainLabels = np.append(lastFullTrainLabels, lbl, axis=0)

# Add validation predictions and labels
for i in range(STEP_SIZE_VALID+1):
    im, lbl = next(valid_generator)
    scores = model.predict(im, batch_size=valid_generator.batch_size)
    lastFullValPred = np.append(lastFullValPred, scores, axis=0)
    lastFullValLabels = np.append(lastFullValLabels, lbl, axis=0)
    
    
lastFullComPred = np.concatenate((lastFullTrainPred, lastFullValPred))
lastFullComLabels = np.concatenate((lastFullTrainLabels, lastFullValLabels))
complete_labels = [np.argmax(label) for label in lastFullComLabels]

train_preds = [np.argmax(pred) for pred in lastFullTrainPred]
train_labels = [np.argmax(label) for label in lastFullTrainLabels]
validation_preds = [np.argmax(pred) for pred in lastFullValPred]
validation_labels = [np.argmax(label) for label in lastFullValLabels]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', figsize=(24, 7))
labels = ['0 - No DR', '1 - Mild', '2 - Moderate', '3 - Severe', '4 - Proliferative DR']
train_cnf_matrix = confusion_matrix(train_labels, train_preds)
validation_cnf_matrix = confusion_matrix(validation_labels, validation_preds)

train_cnf_matrix_norm = train_cnf_matrix.astype('float') / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
validation_cnf_matrix_norm = validation_cnf_matrix.astype('float') / validation_cnf_matrix.sum(axis=1)[:, np.newaxis]

train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=labels, columns=labels)
validation_df_cm = pd.DataFrame(validation_cnf_matrix_norm, index=labels, columns=labels)

sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax1).set_title('Train')
sns.heatmap(validation_df_cm, annot=True, fmt='.2f', cmap=sns.cubehelix_palette(8), ax=ax2).set_title('Validation')
plt.show()

# %% [markdown]
# ## Quadratic Weighted Kappa

# %%
print("Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds,train_labels, weights='quadratic'))
print("Validation Cohen Kappa score: %.3f" % cohen_kappa_score(validation_preds, validation_labels, weights='quadratic'))
print("Complete set Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds+validation_preds, train_labels+validation_labels, weights='quadratic'))

# %%
from sklearn.metrics import confusion_matrix, cohen_kappa_score,accuracy_score
print("Train Accuracy: %.3f" % accuracy_score(train_labels,train_preds))
print("Validation Accuracy: %.3f" % accuracy_score(validation_labels, validation_preds))
print("Complete set Accuracy: %.3f" % accuracy_score(train_labels+validation_labels,train_preds+validation_preds))

# %% [markdown]
# # SHAP Model explainability
#
# #### About SHAP's DeepExplainer from the [source repository](https://github.com/slundberg/shap#deep-learning-example-with-deepexplainer-tensorflowkeras-models):
# - Deep SHAP is a high-speed approximation algorithm for SHAP values in deep learning models that builds on a connection with [DeepLIFT](https://arxiv.org/abs/1704.02685) described in the SHAP NIPS paper. The implementation here differs from the original DeepLIFT by using a distribution of background samples instead of a single reference value, and using Shapley equations to linearize components such as max, softmax, products, divisions, etc.
#
# ### First let's see the images that we will explain

# %%
n_explain = 2
valid_generator.batch_size = 10 # background dataset
background, lbls = next(valid_generator)

sns.set_style("white")
plt.figure(figsize=[8, 8])
for index, image in enumerate(background[:n_explain]):
    plt.subplot(n_explain, 1, index+1)
    plt.imshow(image)
    plt.title("Image %s, Label: %s" % (index, np.argmax(lbls[index])))
    
plt.show()

# %% [markdown]
# ### Now the SHAP explanation

# %%
# explain predictions of the model on "n_explain" images
e = shap.DeepExplainer(model, background)
shap_values = e.shap_values(background)

# plot the feature attributions
shap.image_plot(shap_values, -background[:n_explain], labels=lbls, hspace=0.1)

# %% [markdown]
# - The plot above explains five outputs (our five levels of diabetic retinopathy 0-5) for three different images. Red pixels increase the model's output while blue pixels decrease the output. The input images are shown on the left (they are black because most of the pixels are greater than 0), and as nearly transparent grayscale backings behind each of the explanations. The sum of the SHAP values equals the difference between the expected model output (averaged over the background dataset, here I'm using 10 images) and the current model output.
# - Note that for the images that the label is "1.0" (the correct one), we a greater pink area.
# - Labels that have as much pink area as the correct one are labels that our model probably doesn't have a high confidence prediction.

# %% [markdown]
# ## Let's try on a few more images

# %%
n_explain = 3
background, lbls = next(valid_generator)

sns.set_style("white")
plt.figure(figsize=[12, 12])
for index, image in enumerate(background[:n_explain]):
    plt.subplot(n_explain, 1, index+1)
    plt.imshow(image)
    plt.title("Image %s, Label: %s" % (index, np.argmax(lbls[index])))
    
plt.show()

# %%
# explain predictions of the model on "n_explain" images
e = shap.DeepExplainer(model, background)
shap_values = e.shap_values(background)

# plot the feature attributions
shap.image_plot(shap_values, -background[:n_explain], labels=lbls, hspace=0.1)

# %% [markdown]
# ## Apply model to test set and output predictions

# %%
test_generator.reset()
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size
preds = model.predict_generator(test_generator, steps=STEP_SIZE_TEST)
predictions = [np.argmax(pred) for pred in preds]

filenames = test_generator.filenames
results = pd.DataFrame({'id_code':filenames, 'diagnosis':predictions})
results['id_code'] = results['id_code'].map(lambda x: str(x)[:-4])

# %% [markdown]
# # Predictions class distribution

# %%
fig = plt.subplots(1, 1, sharex='col', figsize=(24, 8.7))
sns.countplot(x="diagnosis", data=results, palette="GnBu_d")
sns.despine()
plt.show()

# %%
results.to_csv('submission.csv', index=False)
results.head(10)

# %%
model.save('vgg.h5')

# %%
print("Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds,train_labels))
print("Validation Cohen Kappa score: %.3f" % cohen_kappa_score(validation_preds, validation_labels))

# %%
kaggle kernels output maryammahmoud/diabetic-retinopathy-shap-model-explainability -p /path/to/dest

# %% [markdown]
# kaggle kernels output maryammahmoud/diabetic-retinopathy-shap-model-explainability -p /path/to/dest

# %% [markdown]
# <a href="/kaggle/working/accuracy90.h5"> Download File </a>
